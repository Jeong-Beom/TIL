# %% [markdown]
# ## 해당 코드는 데이콘 홈페이지 와인 품질 분류대회 EDA에서 제공하는 코드를 참고하였습니다.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import patches
# %matplotlib inline
import os
import numpy as np

# %%
Basic_dir = os.path.dirname(os.path.dirname(os.path.realpath('EDA.ipynb')))
PATH = Basic_dir + '\\Data\\Data(WineQ_B)'
os.listdir(PATH)
# Out:
# ['sample_submission.csv', 'test.csv', 'train.csv']

# %%
train = pd.read_csv(PATH + '\\train.csv')
print(train.columns)
train.head()
# Out:
# Index(['id', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'type',
#        'quality'],
#       dtype='object')
#    id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   1            8.0              0.18         0.37             1.3
# 1   2            7.5              0.38         0.29             4.9
# 2   3            6.1              0.27         0.33             2.2
# 3   4            6.4              0.32         0.50            10.7
# 4   5            8.4              0.37         0.43             2.3
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.040                 15.0                  96.0  0.99120  3.06
# 1      0.021                 38.0                 113.0  0.99026  3.08
# 2      0.021                 26.0                 117.0  0.98860  3.12
# ...

# %%
# 변수 타입 확인 - type변수를 제외한 모든 변수가 연속형 변수
train.dtypes
# Out:
# id                        int64
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# type                     object
# quality                   int64
# dtype: object

# %%
# 결측치 확인 - 결측치 없음
train.isnull().sum().sum()
# Out:
# 0

# %%
# 종속변수 분포도 확인 - 불균형이 심함.
train.quality.value_counts()
# Out:
# 6    1418
# 5    1069
# 7     539
# 4     108
# 8      97
# Name: quality, dtype: int64

# %%
colormap = plt.cm.RdBu
plt.figure(figsize = (20, 20))
plt.title('corr score')
sns.heatmap(train.drop(['type'], axis = 1).corr(), linewidth = 0.1, vmax = 1.0, square = True, cmap = colormap, linecolor = 'white', annot = True, annot_kws = {'size' : 16})
# Out:
# <AxesSubplot:title={'center':'corr score'}>
